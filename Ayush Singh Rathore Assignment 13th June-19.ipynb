# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#   report_date                location location_type  \
# 0  2016-03-19  Argentina-Buenos_Aires      province
# 1  2016-03-19  Argentina-Buenos_Aires      province
# 2  2016-03-19  Argentina-Buenos_Aires      province
# 3  2016-03-19  Argentina-Buenos_Aires      province
# 4  2016-03-19  Argentina-Buenos_Aires      province
# 5  2016-03-19  Argentina-Buenos_Aires      province
# 6  2016-03-19          Argentina-CABA      province
# 7  2016-03-19          Argentina-CABA      province
# 8  2016-03-19          Argentina-CABA      province
# 9  2016-03-19          Argentina-CABA      province
#
#                             data_field data_field_code  time_period  \
# 0     cumulative_confirmed_local_cases          AR0001          NaN
# 1      cumulative_probable_local_cases          AR0002          NaN
# 2  cumulative_confirmed_imported_cases          AR0003          NaN
# 3   cumulative_probable_imported_cases          AR0004          NaN
# ...

# %%
df.dtypes
# Out:
# report_date          object
# location             object
# location_type        object
# data_field           object
# data_field_code      object
# time_period         float64
# time_period_type    float64
# value                object
# unit                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# report_date              7
# location                 7
# location_type            7
# data_field               7
# data_field_code          7
# time_period         107619
# time_period_type    107619
# value                  138
# unit                     7
# dtype: int64

# %%
df.drop(['time_period','time_period_type'],inplace=True,axis=1)

# %%
df.describe()
# Out:
#        report_date                      location location_type  \
# count       107612                        107612        107612
# unique         128                          1673            11
# top     2016-04-23  United_States_Virgin_Islands  municipality
# freq          4677                           413         87557
#
#                        data_field data_field_code   value    unit
# count                      107612          107612  107481  107612
# unique                        148             153    1749       2
# top     zika_confirmed_laboratory          CO0003       0   cases
# freq                        28963           28963   45134  106519

# %% [markdown]
# ## Q1. show data field code 'AR0005' values for 'Argentina-Catamarca' for entire duration

# %%
df_q1 = df[(df['location'] == 'Argentina-Catamarca') & (df['data_field_code'] == 'AR0005')]

# %%
df_q1
# Out:
#      report_date             location location_type  \
# 16    2016-03-19  Argentina-Catamarca      province
# 160   2016-03-26  Argentina-Catamarca      province
# 304   2016-04-02  Argentina-Catamarca      province
# 448   2016-04-09  Argentina-Catamarca      province
# 592   2016-04-16  Argentina-Catamarca      province
# 736   2016-04-29  Argentina-Catamarca      province
# 880   2016-05-07  Argentina-Catamarca      province
# 1024  2016-05-14  Argentina-Catamarca      province
# 1168  2016-05-22  Argentina-Catamarca      province
# 1312  2016-05-30  Argentina-Catamarca      province
# 1456  2016-06-06  Argentina-Catamarca      province
# 1600  2016-06-13  Argentina-Catamarca      province
# 1744  2016-06-18  Argentina-Catamarca      province
# 1888  2016-06-26  Argentina-Catamarca      province
#
#                         data_field data_field_code value   unit
# 16    cumulative_cases_under_study          AR0005    14  cases
# ...

# %% [markdown]
# ## Q2. Plot 'Argentina-CABA' and 'Argentina-Catamarca' for number of cases values for entire duration to identify the difference.

# %%
df_q2_1 = df[(df['location'] == 'Argentina-Catamarca') & (df['unit'] == 'cases')]

# %%
df_q2_1
# Out:
#      report_date             location location_type  \
# 12    2016-03-19  Argentina-Catamarca      province
# 13    2016-03-19  Argentina-Catamarca      province
# 14    2016-03-19  Argentina-Catamarca      province
# 15    2016-03-19  Argentina-Catamarca      province
# 16    2016-03-19  Argentina-Catamarca      province
# 17    2016-03-19  Argentina-Catamarca      province
# 156   2016-03-26  Argentina-Catamarca      province
# 157   2016-03-26  Argentina-Catamarca      province
# 158   2016-03-26  Argentina-Catamarca      province
# 159   2016-03-26  Argentina-Catamarca      province
# 160   2016-03-26  Argentina-Catamarca      province
# 161   2016-03-26  Argentina-Catamarca      province
# 300   2016-04-02  Argentina-Catamarca      province
# 301   2016-04-02  Argentina-Catamarca      province
# 302   2016-04-02  Argentina-Catamarca      province
# 303   2016-04-02  Argentina-Catamarca      province
# 304   2016-04-02  Argentina-Catamarca      province
# ...

# %%
df_q2_1['value'] = pd.to_numeric(df_q2_1['value'],errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_q2_1.head()
df_q2_1.dtypes
# Out:
# report_date        object
# location           object
# location_type      object
# data_field         object
# data_field_code    object
# value               int64
# unit               object
# dtype: object

# %%
df_q2_1.isnull().sum()
# Out:
# report_date        0
# location           0
# location_type      0
# data_field         0
# data_field_code    0
# value              0
# unit               0
# dtype: int64

# %%
df_q2_1['value'].sum()
# Out:
# 212

# %%
df_q2_2 = df[(df['location'] == 'Argentina-CABA') & (df['unit'] == 'cases')]

# %%
df_q2_2.columns
# Out:
# Index(['report_date', 'location', 'location_type', 'data_field',
#        'data_field_code', 'value', 'unit'],
#       dtype='object')

# %%
df_q2_2.head(10)
# Out:
#     report_date        location location_type  \
# 6    2016-03-19  Argentina-CABA      province
# 7    2016-03-19  Argentina-CABA      province
# 8    2016-03-19  Argentina-CABA      province
# 9    2016-03-19  Argentina-CABA      province
# 10   2016-03-19  Argentina-CABA      province
# 11   2016-03-19  Argentina-CABA      province
# 150  2016-03-26  Argentina-CABA      province
# 151  2016-03-26  Argentina-CABA      province
# 152  2016-03-26  Argentina-CABA      province
# 153  2016-03-26  Argentina-CABA      province
#
#                               data_field data_field_code value   unit
# 6       cumulative_confirmed_local_cases          AR0001     0  cases
# 7        cumulative_probable_local_cases          AR0002     0  cases
# 8    cumulative_confirmed_imported_cases          AR0003     9  cases
# 9     cumulative_probable_imported_cases          AR0004     0  cases
# 10          cumulative_cases_under_study          AR0005    68  cases
# ...

# %%
df_q2_2['value'] = pd.to_numeric(df_q2_2['value'],errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_q2_2.head()
df_q2_2.dtypes
# Out:
# report_date        object
# location           object
# location_type      object
# data_field         object
# data_field_code    object
# value               int64
# unit               object
# dtype: object

# %%
plt.bar(['Cata','Caba'],[df_q2_1['value'].sum(),df_q2_2['value'].sum()])
plt.title('Number of Cases per Location')
plt.xlabel('Locations')
plt.ylabel('Sum')
plt.show()

# %% [markdown]
# # 3. Plot how data field values are distributed across the locations 'Argentina-Buenos_Aires', 'Argentina-CABA', 'Argentina-Catamarca'

# %%
df_q3_1=df[(df["location"]=='Argentina-CABA')]
df_q3_2=df[(df["location"]=='Argentina-Catamarca')]
df_q3_3=df[(df["location"]=='Argentina-Buenos_Aires')]

# %%
fig,axes=plt.subplots()
axes.scatter(x=df_q3_1["value"],y=df_q3_1["report_date"],label="CABA")
axes.scatter(x=df_q3_2["value"],y=df_q3_2["report_date"],label="Catamarca",alpha=0.8)
axes.scatter(x=df_q3_3["value"],y=df_q3_3["report_date"],label="Buenos_Aires",alpha=0.5)
axes.legend(loc=0)
axes.set_xlabel("Values")
axes.set_ylabel("Report-Date")
# Out:
# Text(0, 0.5, 'Report-Date')

# %%
df_q3_1["data_field"].value_counts()
# Out:
# cumulative_probable_local_cases        14
# cumulative_confirmed_imported_cases    14
# cumulative_probable_imported_cases     14
# cumulative_confirmed_local_cases       14
# cumulative_cases_under_study           14
# cumulative_cases_discarded             14
# Name: data_field, dtype: int64

# %%
df_q3_2["data_field"].value_counts()
# Out:
# cumulative_probable_local_cases        14
# cumulative_confirmed_imported_cases    14
# cumulative_probable_imported_cases     14
# cumulative_confirmed_local_cases       14
# cumulative_cases_under_study           14
# cumulative_cases_discarded             14
# Name: data_field, dtype: int64

# %%
df_q3_3["data_field"].value_counts()
# Out:
# cumulative_probable_local_cases        14
# cumulative_confirmed_imported_cases    14
# cumulative_probable_imported_cases     14
# cumulative_confirmed_local_cases       14
# cumulative_cases_under_study           14
# cumulative_cases_discarded             14
# Name: data_field, dtype: int64

# %%
df_q3_3_group=df_q3_3.groupby("data_field").agg({'value':'sum'})
df_q3_1_group=df_q3_1.groupby("data_field").agg({'value':'sum'})
df_q3_2_group=df_q3_2.groupby("data_field").agg({'value':'sum'})

# %%
df_q3_1_group.reset_index(inplace=True)
df_q3_2_group.reset_index(inplace=True)
df_q3_3_group.reset_index(inplace=True)

# %%
x_axis=np.arange(1,19,3)

# %%
x_axis
# Out:
# array([ 1,  4,  7, 10, 13, 16])

# %%
plt.figure(figsize=(10,10))
plt.bar(x_axis,df_q3_3_group["value"])
plt.bar(x_axis+1,df_q3_1_group["value"])
plt.bar(x_axis+2,df_q3_2_group["value"])
plt.xticks(np.arange(2,20,3),labels=("cumulative_probable_imported_cases","cumulative_probable_local_cases","cumulative_cases_under_study","cumulative_confirmed_imported_cases","cumulative_confirmed_local_cases","cumulative_cases_discarded"))
plt.xticks(rotation=60)
# Out:
# (array([ 2,  5,  8, 11, 14, 17]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# # 4. Build a program to predict the correct word for wrongly typed word. for example whst => what, numbr =>number, good => good

# %%
import re
from collections import Counter

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('big.txt').read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of word."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
correction("whst")
# Out:
# 'what'

# %%
correction('peterbrg')
# Out:
# 'petersburg'
